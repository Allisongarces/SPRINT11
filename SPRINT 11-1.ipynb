# %% [markdown]
# ### Proyecto Final | Sprint 11 / 1
# #### Allison Garces

# %%
#Importando librerias

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
#Instituto Colombiano para la Evaluación de la Educación - ICFES (2022-1). Datalcfes. Saber 11 ç
#https://www.icfes.gov.co/web/guest/data-icfes

datos = pd.read_csv("Data_Icfes_SABER11_2022-1_v2.csv", sep=";", encoding='latin-1')

# %%
datos.head()
# Out:
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 0                 TI          COLOMBIA           F           10/09/2005
# 1                 TI          COLOMBIA           M           13/03/2005
# 2                 TI          COLOMBIA           F           23/08/2005
# 3                 TI          COLOMBIA           M           08/10/2005
# 4                 TI          COLOMBIA           F           26/11/2003
#
#    PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_PAIS_RESIDE  ESTU_TIENEETNIA  \
# 0  20221.0   AC202210045257      ESTUDIANTE         COLOMBIA              0.0
# 1  20221.0   AC202210007137      ESTUDIANTE         COLOMBIA              0.0
# 2  20221.0   AC202210010953      ESTUDIANTE         COLOMBIA              0.0
# 3  20221.0   AC202210043138      ESTUDIANTE         COLOMBIA              0.0
# 4  20221.0   AC202210019285      ESTUDIANTE         COLOMBIA              0.0
#
# ...

# %%
#Cantidad de datos
datos.shape
# Out:
# (20049, 82)

# %%
#Nombres de las 81 columnas
datos.columns
# Out:
# Index(['ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO',
#        'ESTU_FECHANACIMIENTO', 'PERIODO', 'ESTU_CONSECUTIVO',
#        'ESTU_ESTUDIANTE', 'ESTU_PAIS_RESIDE', 'ESTU_TIENEETNIA',
#        'ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_MCPIO_RESIDE',
#        'ESTU_COD_RESIDE_MCPIO', 'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR',
#        'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE',
#        'FAMI_TRABAJOLABORPADRE', 'FAMI_TRABAJOLABORMADRE',
#        'FAMI_TIENEINTERNET', 'FAMI_TIENESERVICIOTV', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENELAVADORA', 'FAMI_TIENEHORNOMICROOGAS', 'FAMI_TIENEAUTOMOVIL',
#        'FAMI_TIENEMOTOCICLETA', 'FAMI_TIENECONSOLAVIDEOJUEGOS',
#        'FAMI_NUMLIBROS', 'FAMI_COMELECHEDERIVADOS',
#        'FAMI_COMECARNEPESCADOHUEVO', 'FAMI_COMECEREALFRUTOSLEGUMBRE',
#        'FAMI_SITUACIONECONOMICA', 'ESTU_DEDICACIONLECTURADIARIA',
#        'ESTU_DEDICACIONINTERNET', 'ESTU_HORASSEMANATRABAJA',
# ...

# %%
#Eliminando columnas que no son necesarias y dejando solo variables numericas.
data = datos.drop(["ESTU_TIPODOCUMENTO","ESTU_NACIONALIDAD","ESTU_GENERO","ESTU_FECHANACIMIENTO","PERIODO","ESTU_CONSECUTIVO","ESTU_ESTUDIANTE","ESTU_PAIS_RESIDE",
                  "ESTU_DEPTO_RESIDE","ESTU_COD_RESIDE_DEPTO","ESTU_MCPIO_RESIDE","ESTU_COD_RESIDE_MCPIO", "FAMI_EDUCACIONPADRE",
                  "FAMI_EDUCACIONMADRE","FAMI_TRABAJOLABORPADRE","FAMI_TRABAJOLABORMADRE", "FAMI_COMELECHEDERIVADOS", "FAMI_COMECARNEPESCADOHUEVO",
                  "FAMI_COMECEREALFRUTOSLEGUMBRE", "ESTU_HORASSEMANATRABAJA", "ESTU_TIPOREMUNERACION", "COLE_CODIGO_ICFES","COLE_COD_DANE_ESTABLECIMIENTO",
                  "COLE_NOMBRE_ESTABLECIMIENTO", "COLE_GENERO", "COLE_CALENDARIO", "COLE_COD_DANE_SEDE", "COLE_NOMBRE_SEDE", "COLE_SEDE_PRINCIPAL",
                  "COLE_COD_MCPIO_UBICACION", "COLE_MCPIO_UBICACION", "COLE_COD_DEPTO_UBICACION", "COLE_DEPTO_UBICACION","ESTU_PRIVADO_LIBERTAD","ESTU_COD_MCPIO_PRESENTACION", 
                  "ESTU_MCPIO_PRESENTACION", "ESTU_DEPTO_PRESENTACION","ESTU_COD_MCPIO_PRESENTACION", "ESTU_MCPIO_PRESENTACION", "ESTU_DEPTO_PRESENTACION","ESTU_COD_DEPTO_PRESENTACION", 
                  "PERCENTIL_LECTURA_CRITICA", "DESEMP_LECTURA_CRITICA","PERCENTIL_MATEMATICAS", "DESEMP_MATEMATICAS", "PERCENTIL_C_NATURALES","DESEMP_C_NATURALES", 
                  "PERCENTIL_SOCIALES_CIUDADANAS","DESEMP_SOCIALES_CIUDADANAS","PERCENTIL_INGLES","DESEMP_INGLES", "PERCENTIL_GLOBAL", "PERCENTIL_ESPECIAL_GLOBAL","ESTU_INSE_INDIVIDUAL",
                  "ESTU_NSE_INDIVIDUAL","ESTU_NSE_ESTABLECIMIENTO","ESTU_ESTADOINVESTIGACION"], axis=1)

# %%
data.head()
# Out:
#    ESTU_TIENEETNIA  FAMI_ESTRATOVIVIENDA  FAMI_PERSONASHOGAR  \
# 0              0.0                   3.0                 2.0
# 1              0.0                   3.0                 2.0
# 2              0.0                   4.0                 2.0
# 3              0.0                   3.0                 2.0
# 4              0.0                   2.0                 3.0
#
#    FAMI_CUARTOSHOGAR  FAMI_TIENEINTERNET  FAMI_TIENESERVICIOTV  \
# 0                2.0                 1.0                   0.0
# 1                2.0                 1.0                   0.0
# 2                2.0                 1.0                   1.0
# 3                2.0                 1.0                   1.0
# 4                4.0                 1.0                   1.0
#
#    FAMI_TIENECOMPUTADOR  FAMI_TIENELAVADORA  FAMI_TIENEHORNOMICROOGAS  \
# 0                   0.0                 1.0                       0.0
# 1                   1.0                 1.0                       1.0
# ...

# %%
#Nuevo tamaño.
data.shape
# Out:
# (20049, 28)

# %%
data.to_csv('Data_Icfes_SABER11_2022-1_v3.csv')

# %%
#Consultando valores nulos
data.isnull().sum()
# Out:
# ESTU_TIENEETNIA                  183
# FAMI_ESTRATOVIVIENDA            1204
# FAMI_PERSONASHOGAR               936
# FAMI_CUARTOSHOGAR                960
# FAMI_TIENEINTERNET              1109
# FAMI_TIENESERVICIOTV            1150
# FAMI_TIENECOMPUTADOR             969
# FAMI_TIENELAVADORA               972
# FAMI_TIENEHORNOMICROOGAS        1002
# FAMI_TIENEAUTOMOVIL             1017
# FAMI_TIENEMOTOCICLETA            995
# FAMI_TIENECONSOLAVIDEOJUEGOS    1019
# FAMI_NUMLIBROS                  1482
# FAMI_SITUACIONECONOMICA         1006
# ESTU_DEDICACIONLECTURADIARIA    1145
# ESTU_DEDICACIONINTERNET         1168
# COLE_NATURALEZA                  174
# COLE_BILINGUE                   4956
# COLE_CARACTER                   2594
# COLE_AREA_UBICACION              174
# COLE_JORNADA                     174
# PUNT_LECTURA_CRITICA             174
# PUNT_MATEMATICAS                 174
# PUNT_C_NATURALES                 174
# PUNT_SOCIALES_CIUDADANAS         174
# ...

# %%
#Eliminando valores nulos
data = data.dropna()

# %%
#Pasando a numeros enteros todos los datos
data['ESTU_TIENEETNIA'] = data['ESTU_TIENEETNIA'].apply(np.int64)
data['FAMI_ESTRATOVIVIENDA'] = data['FAMI_ESTRATOVIVIENDA'].apply(np.int64)
data['FAMI_PERSONASHOGAR'] = data['FAMI_PERSONASHOGAR'].apply(np.int64)
data['FAMI_CUARTOSHOGAR'] = data['FAMI_CUARTOSHOGAR'].apply(np.int64)
data['FAMI_TIENEINTERNET'] = data['FAMI_TIENEINTERNET'].apply(np.int64)
data['FAMI_TIENESERVICIOTV'] = data['FAMI_TIENESERVICIOTV'].apply(np.int64)
data['FAMI_TIENECOMPUTADOR'] = data['FAMI_TIENECOMPUTADOR'].apply(np.int64)
data['FAMI_TIENELAVADORA'] = data['FAMI_TIENELAVADORA'].apply(np.int64)
data['FAMI_TIENEHORNOMICROOGAS'] = data['FAMI_TIENEHORNOMICROOGAS'].apply(np.int64)
data['FAMI_TIENEAUTOMOVIL'] = data['FAMI_TIENEAUTOMOVIL'].apply(np.int64)
data['FAMI_TIENEMOTOCICLETA'] = data['FAMI_TIENEMOTOCICLETA'].apply(np.int64)
data['FAMI_TIENECONSOLAVIDEOJUEGOS'] = data['FAMI_TIENECONSOLAVIDEOJUEGOS'].apply(np.int64)
data['FAMI_NUMLIBROS'] = data['FAMI_NUMLIBROS'].apply(np.int64)
data['FAMI_SITUACIONECONOMICA'] = data['FAMI_SITUACIONECONOMICA'].apply(np.int64)
data['ESTU_DEDICACIONLECTURADIARIA'] = data['ESTU_DEDICACIONLECTURADIARIA'].apply(np.int64)
data['ESTU_DEDICACIONINTERNET'] = data['ESTU_DEDICACIONINTERNET'].apply(np.int64)
data['COLE_NATURALEZA'] = data['COLE_NATURALEZA'].apply(np.int64)
data['COLE_BILINGUE'] = data['COLE_BILINGUE'].apply(np.int64)
data['COLE_CARACTER'] = data['COLE_CARACTER'].apply(np.int64)
data['COLE_CARACTER'] = data['COLE_CARACTER'].apply(np.int64)
data['COLE_AREA_UBICACION'] = data['COLE_AREA_UBICACION'].apply(np.int64)
data['COLE_JORNADA'] = data['COLE_JORNADA'].apply(np.int64)
data['PUNT_LECTURA_CRITICA'] = data['PUNT_LECTURA_CRITICA'].apply(np.int64)
data['PUNT_MATEMATICAS'] = data['PUNT_MATEMATICAS'].apply(np.int64)
data['PUNT_C_NATURALES'] = data['PUNT_C_NATURALES'].apply(np.int64)
data['PUNT_SOCIALES_CIUDADANAS'] = data['PUNT_SOCIALES_CIUDADANAS'].apply(np.int64)
data['PUNT_INGLES'] = data['PUNT_INGLES'].apply(np.int64)
data['PUNT_GLOBAL'] = data['PUNT_GLOBAL'].apply(np.int64)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13340 entries, 1 to 20040
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ESTU_TIENEETNIA               13340 non-null  int64
#  1   FAMI_ESTRATOVIVIENDA          13340 non-null  int64
#  2   FAMI_PERSONASHOGAR            13340 non-null  int64
#  3   FAMI_CUARTOSHOGAR             13340 non-null  int64
#  4   FAMI_TIENEINTERNET            13340 non-null  int64
#  5   FAMI_TIENESERVICIOTV          13340 non-null  int64
#  6   FAMI_TIENECOMPUTADOR          13340 non-null  int64
#  7   FAMI_TIENELAVADORA            13340 non-null  int64
#  8   FAMI_TIENEHORNOMICROOGAS      13340 non-null  int64
#  9   FAMI_TIENEAUTOMOVIL           13340 non-null  int64
#  10  FAMI_TIENEMOTOCICLETA         13340 non-null  int64
#  11  FAMI_TIENECONSOLAVIDEOJUEGOS  13340 non-null  int64
#  12  FAMI_NUMLIBROS                13340 non-null  int64
# ...

# %%
#Nombre de las columnas actuales
data.columns
# Out:
# Index(['ESTU_TIENEETNIA', 'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR',
#        'FAMI_CUARTOSHOGAR', 'FAMI_TIENEINTERNET', 'FAMI_TIENESERVICIOTV',
#        'FAMI_TIENECOMPUTADOR', 'FAMI_TIENELAVADORA',
#        'FAMI_TIENEHORNOMICROOGAS', 'FAMI_TIENEAUTOMOVIL',
#        'FAMI_TIENEMOTOCICLETA', 'FAMI_TIENECONSOLAVIDEOJUEGOS',
#        'FAMI_NUMLIBROS', 'FAMI_SITUACIONECONOMICA',
#        'ESTU_DEDICACIONLECTURADIARIA', 'ESTU_DEDICACIONINTERNET',
#        'COLE_NATURALEZA', 'COLE_BILINGUE', 'COLE_CARACTER',
#        'COLE_AREA_UBICACION', 'COLE_JORNADA', 'PUNT_LECTURA_CRITICA',
#        'PUNT_MATEMATICAS', 'PUNT_C_NATURALES', 'PUNT_SOCIALES_CIUDADANAS',
#        'PUNT_INGLES', 'PUNT_GLOBAL', 'CALIFICACION'],
#       dtype='object')

# %%
#Guardo cambios
data.to_csv('Data_Icfes_SABER11_2022-1_v5.csv')

# %%
data.describe()
# Out:
#        ESTU_TIENEETNIA  FAMI_ESTRATOVIVIENDA  FAMI_PERSONASHOGAR  \
# count     13340.000000          13340.000000        13340.000000
# mean          0.013493              3.678411            2.195652
# std           0.115378              1.543637            0.705294
# min           0.000000              0.000000            1.000000
# 25%           0.000000              3.000000            2.000000
# 50%           0.000000              4.000000            2.000000
# 75%           0.000000              5.000000            3.000000
# max           1.000000              6.000000            5.000000
#
#        FAMI_CUARTOSHOGAR  FAMI_TIENEINTERNET  FAMI_TIENESERVICIOTV  \
# count       13340.000000        13340.000000          13340.000000
# mean            3.008696            0.945202              0.900675
# std             0.960303            0.227593              0.299110
# min             1.000000            0.000000              0.000000
# ...

# %%
data.corr()
# Out:
#                               ESTU_TIENEETNIA  FAMI_ESTRATOVIVIENDA  \
# ESTU_TIENEETNIA                      1.000000             -0.104017
# FAMI_ESTRATOVIVIENDA                -0.104017              1.000000
# FAMI_PERSONASHOGAR                   0.050469             -0.042393
# FAMI_CUARTOSHOGAR                   -0.023387              0.196038
# FAMI_TIENEINTERNET                  -0.117441              0.310037
# FAMI_TIENESERVICIOTV                -0.071950              0.285751
# FAMI_TIENECOMPUTADOR                -0.100994              0.394787
# FAMI_TIENELAVADORA                  -0.117451              0.289519
# FAMI_TIENEHORNOMICROOGAS            -0.095246              0.453716
# FAMI_TIENEAUTOMOVIL                 -0.072010              0.523574
# FAMI_TIENEMOTOCICLETA                0.060826             -0.247884
# FAMI_TIENECONSOLAVIDEOJUEGOS        -0.074553              0.442177
# FAMI_NUMLIBROS                      -0.056835              0.487718
# ...

# %%
# #Matriz de correlación que mide las relaciones lineales entre las variables. Dibujada con Seaborn. #1
plt.figure(figsize=(20,10))
cor = data.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.savefig('heatmapICFES.png', bbox_inches ="tight", dpi = 300)
plt.show()

# %%
#Eliminando columnas que no aportan
data.drop(['COLE_AREA_UBICACION', 'COLE_NATURALEZA', 'COLE_CARACTER','FAMI_TIENEMOTOCICLETA',
         'FAMI_PERSONASHOGAR', 'ESTU_TIENEETNIA', 'FAMI_TIENELAVADORA', 'ESTU_DEDICACIONLECTURADIARIA',
         'FAMI_CUARTOSHOGAR'], axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13340 entries, 1 to 20040
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   FAMI_ESTRATOVIVIENDA          13340 non-null  int64
#  1   FAMI_TIENEINTERNET            13340 non-null  int64
#  2   FAMI_TIENESERVICIOTV          13340 non-null  int64
#  3   FAMI_TIENECOMPUTADOR          13340 non-null  int64
#  4   FAMI_TIENEHORNOMICROOGAS      13340 non-null  int64
#  5   FAMI_TIENEAUTOMOVIL           13340 non-null  int64
#  6   FAMI_TIENECONSOLAVIDEOJUEGOS  13340 non-null  int64
#  7   FAMI_NUMLIBROS                13340 non-null  int64
#  8   FAMI_SITUACIONECONOMICA       13340 non-null  int64
#  9   ESTU_DEDICACIONINTERNET       13340 non-null  int64
#  10  COLE_BILINGUE                 13340 non-null  int64
#  11  COLE_JORNADA                  13340 non-null  int64
#  12  PUNT_LECTURA_CRITICA          13340 non-null  int64
# ...

# %%
# Visualizacion con Matplotlib #2
plt.figure(figsize=(20,10))
cor = data.corr()
sns.heatmap(cor, annot=True)
plt.savefig('heatmap2ICFES.png', bbox_inches ="tight", dpi = 300)
plt.show()

# %%
#Declarar vector de características y variable de destino
X = data
y = data['CALIFICACION']

# %%
#Convertir variable categórica en enteros
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

data['CALIFICACION'] = le.fit_transform(data['CALIFICACION'])

y = le.transform(y)

# %%
data.to_csv('Data_Icfes_SABER11_2022-1_v6.csv')

# %%
X.head()
# Out:
#    FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_TIENESERVICIOTV  \
# 1                     3                   1                     0
# 2                     4                   1                     1
# 4                     2                   1                     1
# 7                     2                   1                     1
# 9                     4                   1                     1
#
#    FAMI_TIENECOMPUTADOR  FAMI_TIENEHORNOMICROOGAS  FAMI_TIENEAUTOMOVIL  \
# 1                     1                         1                    0
# 2                     1                         0                    1
# 4                     1                         0                    1
# 7                     0                         0                    0
# 9                     1                         1                    1
#
#    FAMI_TIENECONSOLAVIDEOJUEGOS  FAMI_NUMLIBROS  FAMI_SITUACIONECONOMICA  \
# ...

# %%
data['CALIFICACION'].unique()
# Out:
# array([0, 2, 1])

# %%
cols = X.columns

# %%
from sklearn.preprocessing import MinMaxScaler

ms = MinMaxScaler()
X = ms.fit_transform(X)

# %%
X = pd.DataFrame(X, columns=[cols])

# %%
X.head()
# Out:
#   FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET FAMI_TIENESERVICIOTV  \
# 0             0.500000                1.0                  0.0
# 1             0.666667                1.0                  1.0
# 2             0.333333                1.0                  1.0
# 3             0.333333                1.0                  1.0
# 4             0.666667                1.0                  1.0
#
#   FAMI_TIENECOMPUTADOR FAMI_TIENEHORNOMICROOGAS FAMI_TIENEAUTOMOVIL  \
# 0                  1.0                      1.0                 0.0
# 1                  1.0                      0.0                 1.0
# 2                  1.0                      0.0                 1.0
# 3                  0.0                      0.0                 0.0
# 4                  1.0                      1.0                 1.0
#
#   FAMI_TIENECONSOLAVIDEOJUEGOS FAMI_NUMLIBROS FAMI_SITUACIONECONOMICA  \
# 0                          0.0       0.333333                     0.0
# ...

# %%
#Modelo K-Means con dos Clusters

from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2, random_state=0) 
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
#Ubicaciones finales del centroide
kmeans.cluster_centers_
# Out:
# array([[0.40638738, 0.86229635, 0.78568658, 0.70597362, 0.51124903,
#         0.27831652, 0.1859969 , 0.26331782, 0.51454616, 0.47260473,
#         0.01086113, 0.486346  , 0.5362917 , 0.41936065, 0.33305602,
#         0.34287692, 0.52118697, 0.40624381, 0.52143134],
#        [0.74327957, 0.99743402, 0.97311828, 0.99462366, 0.97421799,
#         0.95698925, 0.75427664, 0.66666667, 0.61210899, 0.55929252,
#         0.41959922, 0.85960411, 0.66067571, 0.60464177, 0.5136981 ,
#         0.5311862 , 0.76221041, 0.60517343, 0.03696237]])

# %%
#El valor SSE más bajo
kmeans.inertia_

#Este modelo tiene una inercia muy alta. Por lo tanto, este no es un buen modelo que se ajuste a los datos.
# Out:
# 17816.180811625298

# %%
#Comprobar la calidad de la clasificación por el modelo
labels = kmeans.labels_

# comprobar cuántas de las muestras se etiquetaron correctamente
correct_labels = sum(y == labels)

print("Resultado: %d de %d muestras estaban correctamente etiquetadas." % (correct_labels, y.size))
# Out:
# Resultado: 2452 de 13340 muestras estaban correctamente etiquetadas.

# %%
print('Precisión: {0:0.2f}'. format(correct_labels/float(y.size)))

#Solo el 18% de precisión con nuestro modelo no supervisado.
# Out:
# Precisión: 0.18

# %%
#Metodo del Codo para encontrar el numero optimo de Clusters

from sklearn.cluster import KMeans
cs = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(X)
    cs.append(kmeans.inertia_)
plt.plot(range(1, 11), cs)
plt.title('Metodo del codo')
plt.xlabel('Numbero de clusters')
plt.ylabel('CS')
plt.show()

# %% [markdown]
# - Por el gráfico anterior, podemos ver que hay una torcedura en k=2.
#
# - Por lo tanto, k=2 puede considerarse un buen número del grupo para agrupar estos datos.
#
# - Pero, hemos visto que he logrado una precisión de clasificación débil del 1% con k=2.

# %%
#Localizador de Codo
from kneed import KneeLocator

kl = KneeLocator(range(1, 11), cs, curve="convex", direction="decreasing")
kl.elbow
# Out:
# 3

# %%
#KMEANS con diferentes clusters

# %%
kmeans = KMeans(n_clusters=3, random_state=0)

kmeans.fit(X)

# comprobar cuántas de las muestras se etiquetaron correctamente
labels = kmeans.labels_

correct_labels = sum(y == labels)
print("Resultado: %d de %d muestras estaban correctamente etiquetadas.." % (correct_labels, y.size))
print('Precisión: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Resultado: 3950 de 13340 muestras estaban correctamente etiquetadas..
# Precisión: 0.30

# %%
kmeans = KMeans(n_clusters=4, random_state=0)

kmeans.fit(X)

# comprobar cuántas de las muestras se etiquetaron correctamente
labels = kmeans.labels_

correct_labels = sum(y == labels)
print("Resultado: %d de %d muestras estaban correctamente etiquetadas.." % (correct_labels, y.size))
print('Precisión: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Resultado: 3885 de 13340 muestras estaban correctamente etiquetadas..
# Precisión: 0.29

# %%
kmeans = KMeans(n_clusters=5, random_state=0)

kmeans.fit(X)

# comprobar cuántas de las muestras se etiquetaron correctamente
labels = kmeans.labels_

correct_labels = sum(y == labels)
print("Resultado: %d de %d muestras estaban correctamente etiquetadas.." % (correct_labels, y.size))
print('Precisión: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Resultado: 3357 de 13340 muestras estaban correctamente etiquetadas..
# Precisión: 0.25

# %%
#Precisión relativamente mas alta del 30% con k=3.

# %%
import scipy.cluster.hierarchy as shc

plt.figure(figsize=(10, 7))  
plt.title("Dendogramas")  
dend = shc.dendrogram(shc.linkage(X, method='ward'))

# %%
plt.figure(figsize=(10, 7))  
plt.title("Dendogramas")  
dend = shc.dendrogram(shc.linkage(X, method='ward'))

plt.axhline(y=15, color='r', linestyle='--')

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')  
cluster.fit_predict(X)
# Out:
# array([2, 2, 1, ..., 1, 0, 2], dtype=int64)

# %%
plt.figure(figsize=(10, 7))  
plt.scatter(X['FAMI_ESTRATOVIVIENDA'], X['CALIFICACION'], c=cluster.labels_)

# %%
#Evaluacion
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons
from sklearn.metrics import adjusted_rand_score
from sklearn.metrics import silhouette_score

# Crear instancias de algoritmos k-means y dbscan
kmeans = KMeans(n_clusters=3)
dbscan = DBSCAN(eps=0.3)

# Ajustar los algoritmos a las características
kmeans.fit(X)
dbscan.fit(X)

# Calcule los puntajes de silueta para cada algoritmo
kmeans_silhouette = silhouette_score(X, kmeans.labels_).round(2)
dbscan_silhouette = silhouette_score(X, dbscan.labels_).round(2)

# %%
print(kmeans_silhouette)
print(dbscan_silhouette)
# Out:
# 0.21
# -0.08
